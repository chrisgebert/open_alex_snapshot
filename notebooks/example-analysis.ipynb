# %%
import requests
import duckdb
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# #### 1. Get OpenAlex author data snapshot file locations from most recent manifest

# %%
manifest = requests.get('https://openalex.s3.amazonaws.com/data/authors/manifest').json()

# %%
# get file paths
files = []

for entry in manifest['entries']:
    file = entry['url']
    files.append(file)

print(len(files))
# Out:
# 89

# %% [markdown]
# #### 2. Install `httpfs` and review snapshot data files using `duckdb`

# %%
duckdb.sql("install 'httpfs'; load 'httpfs'; set s3_region='us-east-1';")

# %%
duckdb.sql("select * from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-08-15/part_001.gz', format='newline_delimited', compression='gzip')")
# Out:
# ┌──────────────────────┬──────────────────────┬────────────────┬───┬──────────────┬─────────────┬──────────────────────┐
# │      x_concepts      │ display_name_alter…  │ cited_by_count │ … │ created_date │ works_count │       updated        │
# │ struct(score doubl…  │      varchar[]       │     int64      │   │     date     │    int64    │       varchar        │
# ├──────────────────────┼──────────────────────┼────────────────┼───┼──────────────┼─────────────┼──────────────────────┤
# │ [{'score': 100.0, …  │ [K. Palczynski, K …  │             40 │ … │ 2023-07-21   │           2 │ 2023-08-15T21:27:1…  │
# │ [{'score': 100.0, …  │ [TE Nyirenda, T Ny…  │             40 │ … │ 2023-07-21   │           6 │ 2023-08-15T18:56:5…  │
# │ [{'score': 100.0, …  │ [Gabriela Popek]     │             40 │ … │ 2023-07-21   │           1 │ 2023-08-15T21:27:5…  │
# │ [{'score': 100.0, …  │ [Kristine R. Greer…  │             40 │ … │ 2023-07-21   │           2 │ 2023-08-15T10:56:4…  │
# │ [{'score': 89.3, '…  │ [I.Zh. Zhalsanova,…  │             40 │ … │ 2023-07-21   │          28 │ 2023-08-15T08:42:3…  │
# │ [{'score': 70.0, '…  │ [Charles Morris. W…  │             40 │ … │ 2023-07-21   │          20 │ 2023-08-15T15:07:4…  │
# │ [{'score': 100.0, …  │ [Doraivajan Balasu…  │             40 │ … │ 2023-07-21   │           4 │ 2023-08-15T18:37:0…  │
# │ [{'score': 100.0, …  │ [Veronica Judith P…  │             40 │ … │ 2023-07-21   │           7 │ 2023-08-15T17:04:4…  │
# │ [{'score': 100.0, …  │ [DU Jin-chao, Jinc…  │             40 │ … │ 2023-07-21   │          12 │ 2023-08-15T08:55:5…  │
# │ [{'score': 100.0, …  │ [P.D. Strachan]      │             40 │ … │ 2023-07-21   │           1 │ 2023-08-15T18:40:4…  │
# │          ·           │        ·             │              · │ · │     ·        │           · │          ·           │
# │          ·           │        ·             │              · │ · │     ·        │           · │          ·           │
# │          ·           │        ·             │              · │ · │     ·        │           · │          ·           │
# │ [{'score': 100.0, …  │ [Denise Kaetzel, D…  │             39 │ … │ 2023-07-21   │           2 │ 2023-08-15T06:48:4…  │
# │ [{'score': 100.0, …  │ [Dong-Qing Guo, Gu…  │             39 │ … │ 2023-07-21   │           6 │ 2023-08-15T23:27:0…  │
# │ [{'score': 100.0, …  │ [Ulisses O Melo, U…  │             39 │ … │ 2023-07-21   │           3 │ 2023-08-15T23:54:5…  │
# │ [{'score': 87.5, '…  │ [M. Shiroda, Megan…  │             39 │ … │ 2023-07-21   │           8 │ 2023-08-15T23:32:1…  │
# │ [{'score': 106.3, …  │ [Meryam El Shersha…  │             39 │ … │ 2023-07-21   │          16 │ 2023-08-15T13:52:3…  │
# │ [{'score': 100.0, …  │ [K. Sheth, Karishm…  │             39 │ … │ 2023-07-21   │           4 │ 2023-08-15T02:15:2…  │
# │ [{'score': 100.0, …  │ [Mansour Dodange]    │             39 │ … │ 2023-07-21   │           1 │ 2023-08-15T18:08:2…  │
# │ [{'score': 100.0, …  │ [Catherine Paterso…  │             39 │ … │ 2023-07-21   │           2 │ 2023-08-15T15:05:3…  │
# │ [{'score': 100.0, …  │ [Zhang HongYi, Hon…  │             39 │ … │ 2023-07-21   │           2 │ 2023-08-15T07:20:5…  │
# │ [{'score': 100.0, …  │ [Constance Lapoint…  │             39 │ … │ 2023-07-21   │           2 │ 2023-08-15T16:48:2…  │
# ├──────────────────────┴──────────────────────┴────────────────┴───┴──────────────┴─────────────┴──────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                   16 columns (6 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# #### 3. Explore a small sample of the records in these snapshot files to see how things are structured

# %%
df = duckdb.sql("select * from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-08-15/part_001.gz', format='newline_delimited', compression='gzip') limit 100").df()

# %%
df.columns
# Out:
# Index(['x_concepts', 'display_name_alternatives', 'cited_by_count',
#        'most_cited_work', 'counts_by_year', 'last_known_institution', 'orcid',
#        'display_name', 'summary_stats', 'works_api_url', 'ids', 'id',
#        'updated_date', 'created_date', 'works_count', 'updated'],
#       dtype='object')

# %%
df
# Out:
#                                            x_concepts  \
# 0   [{'score': 100.0, 'level': 1, 'id': 'https://o...
# 1   [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 2   [{'score': 100.0, 'level': 4, 'id': 'https://o...
# 3   [{'score': 100.0, 'level': 1, 'id': 'https://o...
# 4   [{'score': 89.3, 'level': 0, 'id': 'https://op...
# ..                                                ...
# 95  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 96  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 97  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 98  [{'score': 100.0, 'level': 1, 'id': 'https://o...
# 99  [{'score': 77.8, 'level': 0, 'id': 'https://op...
#
#                             display_name_alternatives  cited_by_count  \
# 0                       [K. Palczynski, K Palczynski]              40
# 1   [TE Nyirenda, T Nyirenda, Nyirenda Te, T.E. Ny...              40
# 2                                    [Gabriela Popek]              40
# 3                       [Kristine R. Greer, K. Greer]              40
# 4   [I.Zh. Zhalsanova, И.А. Гончарова, Irina Zhals...              40
# ..                                                ...             ...
# 95  [Christine M. Mayr Marangon, C Marangon, Chris...              40
# 96                                    [Yutaro Sumida]              40
# 97                      [C. A. Atwood, Carlyn Atwood]              40
# 98                                        [Shenlu Xu]              40
# 99  [Kun-Cheng Zhang, Kun-cheng Zhang, Kuncheng Zh...              40
#
#                                       most_cited_work  \
# 0   Potential Biosignatures in Super-Earth Atmosph...
# 1   Using a bus service for transporting sputum sp...
# 2   PCSK9 signaling pathways and their potential i...
# 3   Primary Motor Area Activation during Precision...
# 4   Comorbidity of asthma and hypertension may be ...
# ..                                                ...
# 95  Techniques for Mitigating the Effects of Smoke...
# 96  Chloride intracellular channel protein 2 in ca...
# 97  Effect of Multimodal Analgesia on Opioid Use A...
# 98  Taste characteristics and umami mechanism of n...
# 99  Geobacillus strains that have potential value ...
#
#                                        counts_by_year  \
# 0   [{'cited_by_count': 1, 'year': 2023, 'works_co...
# 1   [{'cited_by_count': 1, 'year': 2023, 'works_co...
# 2   [{'cited_by_count': 12, 'year': 2023, 'works_c...
# 3   [{'cited_by_count': 1, 'year': 2023, 'works_co...
# 4   [{'cited_by_count': 13, 'year': 2023, 'works_c...
# ..                                                ...
# 95  [{'cited_by_count': 10, 'year': 2023, 'works_c...
# 96  [{'cited_by_count': 3, 'year': 2023, 'works_co...
# 97  [{'cited_by_count': 3, 'year': 2023, 'works_co...
# 98  [{'cited_by_count': 20, 'year': 2023, 'works_c...
# 99  [{'cited_by_count': 36, 'year': 2023, 'works_c...
#
#                                last_known_institution  \
# 0   {'country_code': 'DE', 'ror': 'https://ror.org...
# 1   {'country_code': 'MW', 'ror': 'https://ror.org...
# 2   {'country_code': 'PL', 'ror': 'https://ror.org...
# 3   {'country_code': 'US', 'ror': 'https://ror.org...
# 4   {'country_code': 'RU', 'ror': 'https://ror.org...
# ..                                                ...
# 95  {'country_code': 'IT', 'ror': 'https://ror.org...
# 96  {'country_code': 'JP', 'ror': 'https://ror.org...
# 97  {'country_code': 'US', 'ror': 'https://ror.org...
# 98  {'country_code': 'CN', 'ror': 'https://ror.org...
# 99  {'country_code': 'CN', 'ror': 'https://ror.org...
#
#                                     orcid             display_name  \
# 0                                     NaN            K. Palczynski
# 1                                     NaN              Nyirenda Te
# 2                                     NaN           Gabriela Popek
# 3                                     NaN        Kristine R. Greer
# 4   https://orcid.org/0000-0001-6848-7749          И. Ж. Жалсанова
# ..                                    ...                      ...
# 95  https://orcid.org/0000-0001-7826-2295  Christine Mayr Marangon
# 96                                    NaN            Yutaro Sumida
# 97                                    NaN             C. A. Atwood
# 98                                    NaN                Shenlu Xu
# 99  https://orcid.org/0000-0002-0078-8323           Kuncheng Zhang
#
#                                         summary_stats  \
# 0   {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 1   {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 2   {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 3   {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 4   {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# ..                                                ...
# 95  {'cited_by_count': 40, '2yr_i10_index': 2, 'h_...
# 96  {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 97  {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
# 98  {'cited_by_count': 40, '2yr_i10_index': 2, 'h_...
# 99  {'cited_by_count': 40, '2yr_i10_index': 0, 'h_...
#
#                                         works_api_url  \
# 0   https://api.openalex.org/works?filter=author.i...
# 1   https://api.openalex.org/works?filter=author.i...
# 2   https://api.openalex.org/works?filter=author.i...
# 3   https://api.openalex.org/works?filter=author.i...
# 4   https://api.openalex.org/works?filter=author.i...
# ..                                                ...
# 95  https://api.openalex.org/works?filter=author.i...
# 96  https://api.openalex.org/works?filter=author.i...
# 97  https://api.openalex.org/works?filter=author.i...
# 98  https://api.openalex.org/works?filter=author.i...
# 99  https://api.openalex.org/works?filter=author.i...
#
#                                                   ids  \
# 0   {'openalex': 'https://openalex.org/A5003040756...
# 1   {'openalex': 'https://openalex.org/A5003051334...
# 2   {'openalex': 'https://openalex.org/A5003067678...
# 3   {'openalex': 'https://openalex.org/A5003102207...
# 4   {'openalex': 'https://openalex.org/A5003106718...
# ..                                                ...
# 95  {'openalex': 'https://openalex.org/A5004582787...
# 96  {'openalex': 'https://openalex.org/A5004583578...
# 97  {'openalex': 'https://openalex.org/A5004619576...
# 98  {'openalex': 'https://openalex.org/A5004621160...
# 99  {'openalex': 'https://openalex.org/A5004626725...
#
#                                   id                updated_date created_date  \
# 0   https://openalex.org/A5003040756  2023-08-15T21:27:12.541593   2023-07-21
# 1   https://openalex.org/A5003051334  2023-08-15T18:56:52.521905   2023-07-21
# 2   https://openalex.org/A5003067678  2023-08-15T21:27:56.504137   2023-07-21
# 3   https://openalex.org/A5003102207  2023-08-15T10:56:48.314371   2023-07-21
# 4   https://openalex.org/A5003106718  2023-08-15T08:42:33.264095   2023-07-21
# ..                               ...                         ...          ...
# 95  https://openalex.org/A5004582787  2023-08-15T17:31:54.752480   2023-07-21
# 96  https://openalex.org/A5004583578  2023-08-15T22:15:24.172798   2023-07-21
# 97  https://openalex.org/A5004619576  2023-08-15T17:46:30.521235   2023-07-21
# 98  https://openalex.org/A5004621160  2023-08-15T14:23:28.871193   2023-07-21
# 99  https://openalex.org/A5004626725  2023-08-15T07:18:19.741505   2023-07-21
#
#     works_count                     updated
# 0             2  2023-08-15T21:27:12.541593
# 1             6  2023-08-15T18:56:52.521905
# 2             1  2023-08-15T21:27:56.504137
# 3             2  2023-08-15T10:56:48.314371
# 4            28  2023-08-15T08:42:33.264095
# ..          ...                         ...
# 95           11  2023-08-15T17:31:54.752480
# 96            5  2023-08-15T22:15:24.172798
# 97            2  2023-08-15T17:46:30.521235
# 98            2  2023-08-15T14:23:28.871193
# 99           18  2023-08-15T07:18:19.741505
#
# [100 rows x 16 columns]

# %% [markdown]
# ##### Filtering IDs of authors who have been cited (`where cited_by_count != 0`)

# %%
duckdb.sql("select id from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-08-15/part_001.gz', format='newline_delimited', compression='gzip') where cited_by_count != 0")
# Out:
# ┌──────────────────────────────────┐
# │                id                │
# │             varchar              │
# ├──────────────────────────────────┤
# │ https://openalex.org/A5003040756 │
# │ https://openalex.org/A5003051334 │
# │ https://openalex.org/A5003067678 │
# │ https://openalex.org/A5003102207 │
# │ https://openalex.org/A5003106718 │
# │ https://openalex.org/A5003120547 │
# │ https://openalex.org/A5003129271 │
# │ https://openalex.org/A5003144433 │
# │ https://openalex.org/A5003177155 │
# │ https://openalex.org/A5003196082 │
# │                ·                 │
# │                ·                 │
# │                ·                 │
# │ https://openalex.org/A5088374549 │
# │ https://openalex.org/A5088419030 │
# │ https://openalex.org/A5088420402 │
# │ https://openalex.org/A5088439642 │
# │ https://openalex.org/A5088458123 │
# │ https://openalex.org/A5088481895 │
# │ https://openalex.org/A5088484543 │
# │ https://openalex.org/A5088494947 │
# │ https://openalex.org/A5088511620 │
# │ https://openalex.org/A5088519879 │
# ├──────────────────────────────────┤
# │  ? rows (>9999 rows, 20 shown)   │
# └──────────────────────────────────┘

# %% [markdown]
# ##### Unnesting author records by year

# %%
duckdb.sql("select id as author_id, unnest(counts_by_year, recursive := true) from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-08-15/part_000.gz', format='newline_delimited', compression='gzip') limit 200")
# Out:
# ┌──────────────────────────────────┬────────────────┬───────┬─────────────┬────────────────┐
# │            author_id             │ cited_by_count │ year  │ works_count │ oa_works_count │
# │             varchar              │     int64      │ int64 │    int64    │     int64      │
# ├──────────────────────────────────┼────────────────┼───────┼─────────────┼────────────────┤
# │ https://openalex.org/A5066716873 │          76342 │  2023 │        2239 │            843 │
# │ https://openalex.org/A5066716873 │         116480 │  2022 │        2802 │           1380 │
# │ https://openalex.org/A5066716873 │         114486 │  2021 │        2812 │           1453 │
# │ https://openalex.org/A5066716873 │         103164 │  2020 │        2617 │           1298 │
# │ https://openalex.org/A5066716873 │          58837 │  2019 │        2273 │            924 │
# │ https://openalex.org/A5066716873 │          48643 │  2018 │        2010 │            751 │
# │ https://openalex.org/A5066716873 │          41940 │  2017 │        1745 │            681 │
# │ https://openalex.org/A5066716873 │          36301 │  2016 │        1704 │            550 │
# │ https://openalex.org/A5066716873 │          31212 │  2015 │        1637 │            489 │
# │ https://openalex.org/A5066716873 │          26063 │  2014 │        1572 │            393 │
# │                ·                 │            ·   │    ·  │          ·  │             ·  │
# │                ·                 │            ·   │    ·  │          ·  │             ·  │
# │                ·                 │            ·   │    ·  │          ·  │             ·  │
# │ https://openalex.org/A5003759585 │          12144 │  2013 │         642 │            171 │
# │ https://openalex.org/A5003759585 │          10265 │  2012 │         533 │            103 │
# │ https://openalex.org/A5063481044 │          37808 │  2023 │        1227 │            469 │
# │ https://openalex.org/A5063481044 │          55269 │  2022 │        1559 │            804 │
# │ https://openalex.org/A5063481044 │          48609 │  2021 │        1492 │            727 │
# │ https://openalex.org/A5063481044 │          40658 │  2020 │        1434 │            729 │
# │ https://openalex.org/A5063481044 │          31376 │  2019 │        1180 │            475 │
# │ https://openalex.org/A5063481044 │          26101 │  2018 │        1062 │            378 │
# │ https://openalex.org/A5063481044 │          21976 │  2017 │         938 │            373 │
# │ https://openalex.org/A5063481044 │          18123 │  2016 │         895 │            326 │
# ├──────────────────────────────────┴────────────────┴───────┴─────────────┴────────────────┤
# │ 200 rows (20 shown)                                                            5 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ##### Getting the `display_name` from `last_known_institution`

# %%
duckdb.sql("select id, display_name, json_extract(last_known_institution, '$.display_name'), works_count, cited_by_count from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-08-15/part_000.gz', format='newline_delimited', compression='gzip') where cited_by_count > 10")
# Out:
# ┌──────────────────────┬──────────────────────┬─────────────────────────────────────────┬─────────────┬────────────────┐
# │          id          │     display_name     │ json_extract(last_known_institution, …  │ works_count │ cited_by_count │
# │       varchar        │       varchar        │                  json                   │    int64    │     int64      │
# ├──────────────────────┼──────────────────────┼─────────────────────────────────────────┼─────────────┼────────────────┤
# │ https://openalex.o…  │ Li Zhang             │ "Beijing University of Technology"      │       31086 │         583108 │
# │ https://openalex.o…  │ Eric S. Lander       │ "Center for Systems Biology"            │         979 │         474366 │
# │ https://openalex.o…  │ Ahmedin Jemal        │ "American Cancer Society"               │         872 │         452731 │
# │ https://openalex.o…  │ Jing Wang            │ "Institute of Mechanics"                │       25475 │         430446 │
# │ https://openalex.o…  │ Lei Wang             │ "Beijing University of Chinese Medici…  │       25811 │         414146 │
# │ https://openalex.o…  │ David Moher          │ "Ottawa Hospital"                       │        1456 │         411103 │
# │ https://openalex.o…  │ Yan Wang             │ "Capital Medical University"            │       28561 │         391928 │
# │ https://openalex.o…  │ Yang Liu             │ "Kunming University of Science and Te…  │       26193 │         385617 │
# │ https://openalex.o…  │ Jian Wang            │ "Taiyuan University of Technology"      │       17860 │         375769 │
# │ https://openalex.o…  │ Walter C. Willett    │ "Brigham and Women's Hospital"          │        2892 │         372633 │
# │          ·           │         ·            │               ·                         │          ·  │            ·   │
# │          ·           │         ·            │               ·                         │          ·  │            ·   │
# │          ·           │         ·            │               ·                         │          ·  │            ·   │
# │ https://openalex.o…  │ G. P. Dubois-Felsm…  │ "Infrared Processing and Analysis Cen…  │         862 │          25747 │
# │ https://openalex.o…  │ Karen Bush           │ "University of Pennsylvania"            │         321 │          25744 │
# │ https://openalex.o…  │ B. Epp               │ "Innsbruck Medical University"          │         366 │          25742 │
# │ https://openalex.o…  │ B. B. Miller         │ "University of Amsterdam"               │         109 │          25739 │
# │ https://openalex.o…  │ Liying Wang          │ "Xi'an Technological University"        │        1451 │          25737 │
# │ https://openalex.o…  │ P. R. Christensen    │ "Arizona State University"              │         671 │          25735 │
# │ https://openalex.o…  │ P. Filip             │ "Icahn School of Medicine at Mount Si…  │         527 │          25733 │
# │ https://openalex.o…  │ T. Don Tilley        │ "University of California, Berkeley"    │         628 │          25731 │
# │ https://openalex.o…  │ Stefan Schaal        │ "Intrinsic LifeSciences (United State…  │         583 │          25729 │
# │ https://openalex.o…  │ Linqi Zhang          │ "Hebei University of Chinese Medicine"  │         424 │          25727 │
# ├──────────────────────┴──────────────────────┴─────────────────────────────────────────┴─────────────┴────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                              5 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
