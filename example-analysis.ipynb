# %%
import duckdb
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()

# %% [markdown]
# #### Review a snapshot data file using `duckdb`

# %%
duckdb.sql("install 'httpfs'; load 'httpfs'; set s3_region='us-east-1';")

# %%
duckdb.sql("select count(*) from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-07-21/part_000.gz', format='newline_delimited', compression='gzip')")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
# │      1356380 │
# └──────────────┘

# %%
duckdb.sql("select * from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-07-21/part_000.gz', format='newline_delimited', compression='gzip')")
# Out:
# ┌──────────────────────┬──────────────────────┬────────────────┬───┬──────────────┬─────────────┬────────────┐
# │      x_concepts      │ display_name_alter…  │ cited_by_count │ … │ created_date │ works_count │  updated   │
# │ struct(score doubl…  │      varchar[]       │     int64      │   │     date     │    int64    │    date    │
# ├──────────────────────┼──────────────────────┼────────────────┼───┼──────────────┼─────────────┼────────────┤
# │ [{'score': 100.0, …  │ [J W Chappell, JB …  │           1840 │ … │ 2023-07-21   │           3 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Runa Patel]         │           1293 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Basket-Late Inves…  │           1273 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 41.7, '…  │ [Syaiful Bahri Dja…  │           1269 │ … │ 2023-07-21   │          12 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [L McVay-Boudreau]   │           1233 │ … │ 2023-07-21   │           7 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [E. Y. Chen]         │           1207 │ … │ 2023-07-21   │           2 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Sven-Erik Torhell]  │           1176 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [D. B. Payne]        │           1079 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Gard Pd]            │           1061 │ … │ 2023-07-21   │           4 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Frank Ostrander]    │           1057 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │          ·           │        ·             │             ·  │ · │     ·        │           · │     ·      │
# │          ·           │        ·             │             ·  │ · │     ·        │           · │     ·      │
# │          ·           │        ·             │             ·  │ · │     ·        │           · │     ·      │
# │ [{'score': 100.0, …  │ [David Menapace]     │            173 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Jenny Matilde Gui…  │            173 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Ah-Keng Kau]        │            173 │ … │ 2023-07-21   │           2 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Y. Ye]              │            173 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Jih Fei Cheng]      │            172 │ … │ 2023-07-21   │           1 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [M.-C. Hameau, M.C…  │            172 │ … │ 2023-07-21   │           4 │ 2023-07-21 │
# │ [{'score': 50.0, '…  │ [John Jukes]         │            172 │ … │ 2023-07-21   │           2 │ 2023-07-21 │
# │ [{'score': 87.5, '…  │ [M. Eccleston, M E…  │            172 │ … │ 2023-07-21   │           8 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Lawn Sd]            │            172 │ … │ 2023-07-21   │           4 │ 2023-07-21 │
# │ [{'score': 100.0, …  │ [Jyunichi Kajiwara]  │            172 │ … │ 2023-07-21   │           4 │ 2023-07-21 │
# ├──────────────────────┴──────────────────────┴────────────────┴───┴──────────────┴─────────────┴────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                         16 columns (6 shown) │
# └────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# #### Explore a small sample of the records to explore the data model

# %%
df = duckdb.sql("select * from read_json_auto('https://openalex.s3.amazonaws.com/data/authors/updated_date%3D2023-07-21/part_000.gz', format='newline_delimited', compression='gzip') limit 100").df()

# %%
df.columns
# Out:
# Index(['x_concepts', 'display_name_alternatives', 'cited_by_count',
#        'most_cited_work', 'counts_by_year', 'last_known_institution', 'orcid',
#        'display_name', 'summary_stats', 'works_api_url', 'ids', 'id',
#        'updated_date', 'created_date', 'works_count', 'updated'],
#       dtype='object')

# %%
df
# Out:
#                                            x_concepts  \
# 0   [{'score': 100.0, 'level': 1, 'id': 'https://o...
# 1   [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 2   [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 3   [{'score': 41.7, 'level': 0, 'id': 'https://op...
# 4   [{'score': 100.0, 'level': 1, 'id': 'https://o...
# ..                                                ...
# 95  [{'score': 100.0, 'level': 1, 'id': 'https://o...
# 96  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 97  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 98  [{'score': 100.0, 'level': 0, 'id': 'https://o...
# 99  [{'score': 75.0, 'level': 0, 'id': 'https://op...
#
#          display_name_alternatives  cited_by_count  \
# 0      [J W Chappell, JB Chappell]            1840
# 1                     [Runa Patel]            1293
# 2      [Basket-Late Investigators]            1273
# 3         [Syaiful Bahri Djamarah]            1269
# 4               [L McVay-Boudreau]            1233
# ..                             ...             ...
# 95     [J S McKinney, JS McKinney]             652
# 96                   [Z. P. Zhang]             650
# 97                         [Y. Li]             650
# 98                    [X. L. Wang]             650
# 99  [E. G. Moore, Ernest G. Moore]             649
#
#                                       most_cited_work  \
# 0   A simple method for the preparation of 32P-lab...
# 1   Forskningsmetodikens grunder. Att planera, gen...
# 2   Late Clinical Events After Clopidogrel Discont...
# 3                    Strategi Belajar Mengajar (2002)
# 4   Immunoregulatory circuits among T-cell sets. I...
# ..                                                ...
# 95  Inositol 1,4,5-trisphosphate and inositol 1,3,...
# 96  Transverse Momentum and Centrality Dependence ...
# 97  Transverse Momentum and Centrality Dependence ...
# 98  Transverse Momentum and Centrality Dependence ...
# 99        Congenital Cytomegalovirus Infection (1982)
#
#                                        counts_by_year last_known_institution  \
# 0   [{'cited_by_count': 2, 'year': 2023, 'works_co...                    NaN
# 1   [{'cited_by_count': 2, 'year': 2021, 'works_co...                    NaN
# 2   [{'cited_by_count': 6, 'year': 2023, 'works_co...                    NaN
# 3   [{'cited_by_count': 76, 'year': 2021, 'works_c...                    NaN
# 4   [{'cited_by_count': 1, 'year': 2023, 'works_co...                    NaN
# ..                                                ...                    ...
# 95  [{'cited_by_count': 1, 'year': 2022, 'works_co...                    NaN
# 96  [{'cited_by_count': 6, 'year': 2023, 'works_co...                    NaN
# 97  [{'cited_by_count': 6, 'year': 2023, 'works_co...                    NaN
# 98  [{'cited_by_count': 6, 'year': 2023, 'works_co...                    NaN
# 99  [{'cited_by_count': 2, 'year': 2023, 'works_co...                    NaN
#
#    orcid               display_name  \
# 0    NaN               J W Chappell
# 1    NaN                 Runa Patel
# 2    NaN  Basket-Late Investigators
# 3    NaN     Syaiful Bahri Djamarah
# 4    NaN           L McVay-Boudreau
# ..   ...                        ...
# 95   NaN               J S McKinney
# 96   NaN                Z. P. Zhang
# 97   NaN                      Y. Li
# 98   NaN                 X. L. Wang
# 99   NaN            Ernest G. Moore
#
#                                         summary_stats  \
# 0   {'cited_by_count': 1840, '2yr_i10_index': 0, '...
# 1   {'cited_by_count': 1293, '2yr_i10_index': 0, '...
# 2   {'cited_by_count': 1273, '2yr_i10_index': 0, '...
# 3   {'cited_by_count': 1269, '2yr_i10_index': 0, '...
# 4   {'cited_by_count': 1233, '2yr_i10_index': 0, '...
# ..                                                ...
# 95  {'cited_by_count': 652, '2yr_i10_index': 0, 'h...
# 96  {'cited_by_count': 650, '2yr_i10_index': 0, 'h...
# 97  {'cited_by_count': 650, '2yr_i10_index': 0, 'h...
# 98  {'cited_by_count': 650, '2yr_i10_index': 0, 'h...
# 99  {'cited_by_count': 649, '2yr_i10_index': 0, 'h...
#
#                                         works_api_url  \
# 0   https://api.openalex.org/works?filter=author.i...
# 1   https://api.openalex.org/works?filter=author.i...
# 2   https://api.openalex.org/works?filter=author.i...
# 3   https://api.openalex.org/works?filter=author.i...
# 4   https://api.openalex.org/works?filter=author.i...
# ..                                                ...
# 95  https://api.openalex.org/works?filter=author.i...
# 96  https://api.openalex.org/works?filter=author.i...
# 97  https://api.openalex.org/works?filter=author.i...
# 98  https://api.openalex.org/works?filter=author.i...
# 99  https://api.openalex.org/works?filter=author.i...
#
#                                                   ids  \
# 0   {'openalex': 'https://openalex.org/A5022292925...
# 1   {'openalex': 'https://openalex.org/A5064913229...
# 2   {'openalex': 'https://openalex.org/A5067701857...
# 3   {'openalex': 'https://openalex.org/A5080646503...
# 4   {'openalex': 'https://openalex.org/A5034559380...
# ..                                                ...
# 95  {'openalex': 'https://openalex.org/A5040071334...
# 96  {'openalex': 'https://openalex.org/A5018610379...
# 97  {'openalex': 'https://openalex.org/A5076127104...
# 98  {'openalex': 'https://openalex.org/A5079803399...
# 99  {'openalex': 'https://openalex.org/A5055677029...
#
#                                   id updated_date created_date  works_count  \
# 0   https://openalex.org/A5022292925   2023-07-21   2023-07-21            3
# 1   https://openalex.org/A5064913229   2023-07-21   2023-07-21            1
# 2   https://openalex.org/A5067701857   2023-07-21   2023-07-21            1
# 3   https://openalex.org/A5080646503   2023-07-21   2023-07-21           12
# 4   https://openalex.org/A5034559380   2023-07-21   2023-07-21            7
# ..                               ...          ...          ...          ...
# 95  https://openalex.org/A5040071334   2023-07-21   2023-07-21            8
# 96  https://openalex.org/A5018610379   2023-07-21   2023-07-21            2
# 97  https://openalex.org/A5076127104   2023-07-21   2023-07-21            2
# 98  https://openalex.org/A5079803399   2023-07-21   2023-07-21            2
# 99  https://openalex.org/A5055677029   2023-07-21   2023-07-21            4
#
#       updated
# 0  2023-07-21
# 1  2023-07-21
# 2  2023-07-21
# 3  2023-07-21
# 4  2023-07-21
# ..        ...
# 95 2023-07-21
# 96 2023-07-21
# 97 2023-07-21
# 98 2023-07-21
# 99 2023-07-21
#
# [100 rows x 16 columns]

# %%
duckdb.sql("select count(*) from read_json_auto('/Users/m20/projects/open_alex_authors/data/authors/*/*.gz', format='newline_delimited', compression='gzip')")
# Out:
# ┌──────────────┐
# │ count_star() │
# │    int64     │
# ├──────────────┤
#
# 2023-09-22 09:56:09  536.7 MiB data/authors/updated_date=2023-09-20/part_001.gz
# 2023-09-22 09:56:11  347.8 MiB data/authors/updated_date=2023-09-20/part_002.gz
#
# Total Objects: 105
#    Total Size: 28.1 GiB

# %% [markdown]
# ##### Filtering IDs of authors who have been cited (`where cited_by_count != 0`)

# %%
con = duckdb.connect('open_alex_authors.duckdb')
con.sql("select id from open_alex_authors.september_2023_snapshot where cited_by_count != 0")
# Out:
# ┌──────────────────────────────────┐
# │                id                │
# │             varchar              │
# ├──────────────────────────────────┤
# │ https://openalex.org/A5056528844 │
# │ https://openalex.org/A5019326658 │
# │ https://openalex.org/A5056649904 │
# │ https://openalex.org/A5082777400 │
# │ https://openalex.org/A5016357520 │
# │ https://openalex.org/A5061059691 │
# │ https://openalex.org/A5024931330 │
# │ https://openalex.org/A5010910238 │
# │ https://openalex.org/A5032086815 │
# │ https://openalex.org/A5053724899 │
# │                ·                 │
# │                ·                 │
# │                ·                 │
# │ https://openalex.org/A5072601511 │
# │ https://openalex.org/A5072619972 │
# │ https://openalex.org/A5087342123 │
# │ https://openalex.org/A5087496243 │
# │ https://openalex.org/A5003114427 │
# │ https://openalex.org/A5009904364 │
# │ https://openalex.org/A5020931994 │
# │ https://openalex.org/A5031921539 │
# │ https://openalex.org/A5044059063 │
# │ https://openalex.org/A5045713584 │
# ├──────────────────────────────────┤
# │  ? rows (>9999 rows, 20 shown)   │
# └──────────────────────────────────┘

# %% [markdown]
# ##### Unnesting author records by year

# %%
con.sql("select id as author_id, unnest(counts_by_year, recursive := true) from open_alex_authors.september_2023_snapshot")
# Out:
# ┌──────────────────────────────────┬────────────────┬───────┬─────────────┬────────────────┐
# │            author_id             │ cited_by_count │ year  │ works_count │ oa_works_count │
# │             varchar              │     int64      │ int64 │    int64    │     int64      │
# ├──────────────────────────────────┼────────────────┼───────┼─────────────┼────────────────┤
# │ https://openalex.org/A5056528844 │             60 │  2023 │           0 │              0 │
# │ https://openalex.org/A5056528844 │             99 │  2022 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            121 │  2021 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            129 │  2020 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            100 │  2019 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            143 │  2018 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            144 │  2017 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            155 │  2016 │           1 │              0 │
# │ https://openalex.org/A5056528844 │            162 │  2015 │           0 │              0 │
# │ https://openalex.org/A5056528844 │            193 │  2014 │           0 │              0 │
# │                ·                 │              · │    ·  │           · │              · │
# │                ·                 │              · │    ·  │           · │              · │
# │                ·                 │              · │    ·  │           · │              · │
# │ https://openalex.org/A5036036320 │             43 │  2018 │           0 │              0 │
# │ https://openalex.org/A5036036320 │             41 │  2017 │           0 │              0 │
# │ https://openalex.org/A5036036320 │             56 │  2016 │           0 │              0 │
# │ https://openalex.org/A5036036320 │             70 │  2015 │           0 │              0 │
# │ https://openalex.org/A5036036320 │            105 │  2014 │           2 │              0 │
# │ https://openalex.org/A5036036320 │            133 │  2013 │           0 │              0 │
# │ https://openalex.org/A5036036320 │            112 │  2012 │           1 │              0 │
# │ https://openalex.org/A5077085067 │              8 │  2022 │           0 │              0 │
# │ https://openalex.org/A5077085067 │              3 │  2021 │           0 │              0 │
# │ https://openalex.org/A5077085067 │             10 │  2020 │           0 │              0 │
# ├──────────────────────────────────┴────────────────┴───────┴─────────────┴────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                  5 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ##### Getting the `display_name` from `last_known_institution`

# %%
con.sql("select id, display_name, json_extract(last_known_institution, '$.display_name'), works_count, cited_by_count from open_alex_authors.september_2023_snapshot where cited_by_count > 10")
# Out:
# ┌──────────────────────┬──────────────────────┬─────────────────────────────────────────┬─────────────┬────────────────┐
# │          id          │     display_name     │ json_extract(last_known_institution, …  │ works_count │ cited_by_count │
# │       varchar        │       varchar        │                  json                   │    int64    │     int64      │
# ├──────────────────────┼──────────────────────┼─────────────────────────────────────────┼─────────────┼────────────────┤
# │ https://openalex.o…  │ G C Ebers            │ "University of Oxford"                  │         110 │           7912 │
# │ https://openalex.o…  │ Earl L. Giller       │ "Center for Telepsychology"             │         111 │           6606 │
# │ https://openalex.o…  │ James W. Prichard    │ "The Alfred Hospital"                   │         170 │           6546 │
# │ https://openalex.o…  │ Kiang-Teck Yeo       │ "Magee-Womens Hospital"                 │          45 │           6292 │
# │ https://openalex.o…  │ Joaquim Puig-Antich  │ "University of Pittsburgh"              │          85 │           6182 │
# │ https://openalex.o…  │ Melvin J. Silver     │ "University of Naples Federico II"      │         120 │           6167 │
# │ https://openalex.o…  │ I. Hamamoto          │ "Lund University"                       │         195 │           5976 │
# │ https://openalex.o…  │ R. Dale Wilson       │ "Michigan State University"             │          36 │           5621 │
# │ https://openalex.o…  │ H. J. Leamy          │ "University of North Carolina at Char…  │         125 │           5285 │
# │ https://openalex.o…  │ G. J.H. Boers        │ "Radboud University Nijmegen"           │           1 │           5278 │
# │          ·           │     ·                │           ·                             │           · │             ·  │
# │          ·           │     ·                │           ·                             │           · │             ·  │
# │          ·           │     ·                │           ·                             │           · │             ·  │
# │ https://openalex.o…  │ L.A. Braby           │ "Texas A&M University"                  │         181 │           1196 │
# │ https://openalex.o…  │ Michael L. Accorsi   │ "University of Connecticut"             │          81 │           1196 │
# │ https://openalex.o…  │ Donald G. Fischer    │ "University of Saskatchewan"            │          48 │           1196 │
# │ https://openalex.o…  │ Claudia M. Rezende   │ "Federal University of Rio de Janeiro"  │          84 │           1196 │
# │ https://openalex.o…  │ Y. Uehara            │ "Tohoku University"                     │         103 │           1195 │
# │ https://openalex.o…  │ P.M. Varangis        │ "Laser Operations (United States)"      │          48 │           1195 │
# │ https://openalex.o…  │ X. D. Liu            │ "National Superconducting Cyclotron L…  │          17 │           1195 │
# │ https://openalex.o…  │ Hilde Dosogne        │ "Ghent University"                      │          62 │           1195 │
# │ https://openalex.o…  │ R. G. Robinson       │ "Wellington Hospital"                   │          52 │           1195 │
# │ https://openalex.o…  │ Michael J. McDermott │ "University of Louisiana at Lafayette"  │          67 │           1195 │
# ├──────────────────────┴──────────────────────┴─────────────────────────────────────────┴─────────────┴────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                              5 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
con.close()
